# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
from sklearn import linear_model

# %%
data = pd.read_csv('data_v1.csv')
name = data.columns.values
name = np.array(['gvkey', 'date', 'fyear', 'fquarter', 'industry_format', 'consol',
       'popsrc', 'datafmt', 'ticker', 'cusip', 'conpany_name', 'currency', 'calendaryr_quarter',
       'fiscalyear_qtr', 'total_asset', 'cash', 'st_debt', 'lt_debt', 'net_income', 'ebitda',
       'int_exp', 'exchange', 'status', 'mkt_val', 'group', 'industry', 'sector',
       'subindustry'])

# %%
data.columns = name
data.head()
# Out:
#    gvkey      date  fyear  fquarter industry_format consol popsrc datafmt  \
# 0   1004  19900228   1989         3            INDL      C      D     STD
# 1   1004  19900531   1989         4            INDL      C      D     STD
# 2   1004  19900831   1990         1            INDL      C      D     STD
# 3   1004  19901130   1990         2            INDL      C      D     STD
# 4   1004  19910228   1990         3            INDL      C      D     STD
#
#   ticker   cusip     ...      net_income  ebitda int_exp exchange  status  \
# 0    AIR  361105     ...           6.109  14.251   2.758       11       A
# 1    AIR  361105     ...           6.224  13.137   2.309       11       A
# 2    AIR  361105     ...           6.697  15.400   2.607       11       A
# 3    AIR  361105     ...           0.126   8.871   2.708       11       A
# 4    AIR  361105     ...           3.977  11.344   2.587       11       A
#
#    mkt_val   group  industry  sector  subindustry
# 0      NaN  2010.0  201010.0    20.0   20101010.0
# 1      NaN  2010.0  201010.0    20.0   20101010.0
# 2      NaN  2010.0  201010.0    20.0   20101010.0
# 3      NaN  2010.0  201010.0    20.0   20101010.0
# 4      NaN  2010.0  201010.0    20.0   20101010.0
#
# [5 rows x 28 columns]

# %%
# there is no dual-listing
a = data[['ticker','exchange']].drop_duplicates().groupby('ticker').count()
a[a['exchange'] != 1]
# Out:
# Empty DataFrame
# Columns: [exchange]
# Index: []

# %%
# how many company compustst is inactively updating the data
# when compustat stop track the data, we believe the company will not be included in the top 1000 market cap range.
# so not affecting our analysis
len(data[data['status']== 'I']['ticker'].unique())
# Out:
# 8536

# %%
len(data[data['status']== 'A']['ticker'].unique())
# Out:
# 5576

# %%
# check if any company have 2 status
# if a company is not updated by the database anymore,
# the status changed to I for each time period before

inactive = data[data['status']== 'I']['ticker'].unique()
active = data[data['status']== 'A']['ticker'].unique()
duplicates = []
for ticker in inactive:
    if ticker in active:
        duplicates.append(inactive[i])
duplicates
# Out:
# []

# %%
# 0(n)
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 
   
print(intersection(inactive, active))
# Out:
# []

# %%
len(data['ticker'].unique())
# Out:
# 14111

# %%
data[data['ticker']=='BAM'].tail()
# Out:
#        gvkey      date  fyear  fquarter industry_format consol popsrc datafmt  \
# 20258   2369  20180930   2018         3            INDL      C      D     STD
# 20259   2369  20181231   2018         4            INDL      C      D     STD
# 20260   2369  20190331   2019         1            INDL      C      D     STD
# 20261   2369  20190630   2019         2            INDL      C      D     STD
# 20262   2369  20190930   2019         3            INDL      C      D     STD
#
#       ticker      cusip     ...      net_income  ebitda int_exp exchange  \
# 20258    BAM  112585104     ...           163.0  3010.0  1274.0       11
# 20259    BAM  112585104     ...          1884.0  3883.0  1477.0       11
# 20260    BAM  112585104     ...           615.0  3629.0  1616.0       11
# 20261    BAM  112585104     ...           399.0  4405.0  1833.0       11
# 20262    BAM  112585104     ...           947.0  3993.0  1926.0       11
#
#        status     mkt_val   group  industry  sector  subindustry
# 20258       A  42698.7038  4020.0  402030.0    40.0   40203010.0
# 20259       A  36629.7341  4020.0  402030.0    40.0   40203010.0
# 20260       A  44565.3048  4020.0  402030.0    40.0   40203010.0
# 20261       A  45671.2297  4020.0  402030.0    40.0   40203010.0
# 20262       A  53474.1592  4020.0  402030.0    40.0   40203010.0
#
# [5 rows x 28 columns]

# %%
# make sure data is sorted by ticker and time ascendingly
#data.sort_values(by = ['ticker','date'],ascending = True, inplace = True)

# %%
data.tail()
# Out:
#          gvkey      date  fyear  fquarter industry_format consol popsrc  \
# 667110  330227  20190331   2019         2            INDL      C      D
# 667111  330227  20190630   2019         3            INDL      C      D
# 667112  331856  20190331   2019         1            INDL      C      D
# 667113  331856  20190630   2019         2            INDL      C      D
# 667114  331856  20190930   2019         3            INDL      C      D
#
#        datafmt ticker      cusip     ...      net_income ebitda int_exp  \
# 667110     STD   CTRM  Y1146L109     ...           0.056  0.225     NaN
# 667111     STD   CTRM  Y1146L109     ...           0.261  0.421     NaN
# 667112     STD   IMUX  4525EP101     ...          -4.313 -4.157     NaN
# 667113     STD   IMUX  4525EP101     ...         -14.714 -6.783     NaN
# 667114     STD   IMUX  4525EP101     ...          -8.215 -8.068     NaN
#
#        exchange  status   mkt_val   group  industry  sector  subindustry
# 667110       14       A   13.1282  2030.0  203030.0    20.0   20303010.0
# 667111       14       A   10.2480  2030.0  203030.0    20.0   20303010.0
# 667112       14       A       NaN  3520.0  352010.0    35.0   35201010.0
# 667113       14       A  114.5394  3520.0  352010.0    35.0   35201010.0
# 667114       14       A  100.7100  3520.0  352010.0    35.0   35201010.0
#
# [5 rows x 28 columns]

# %%
# ret is the table we will be used for analysis
ret = data[['fiscalyear_qtr', 'ticker', 'conpany_name','calendaryr_quarter', 'total_asset', 'st_debt', 'lt_debt', 'net_income', 'ebitda',
       'int_exp', 'exchange', 'status', 'mkt_val','industry', 'sector']].copy()
ret['ROA'] = ret['net_income']/ret['total_asset']
ret['total_debt'] = ret['st_debt']+ret['lt_debt']
ret['D/A'] = ret['total_debt']+ret['total_asset']

# %%
data[data['ticker']=='BAM'].tail()
# Out:
#        gvkey      date  fyear  fquarter industry_format consol popsrc datafmt  \
# 20258   2369  20180930   2018         3            INDL      C      D     STD
# 20259   2369  20181231   2018         4            INDL      C      D     STD
# 20260   2369  20190331   2019         1            INDL      C      D     STD
# 20261   2369  20190630   2019         2            INDL      C      D     STD
# 20262   2369  20190930   2019         3            INDL      C      D     STD
#
#       ticker      cusip     ...      net_income  ebitda int_exp exchange  \
# 20258    BAM  112585104     ...           163.0  3010.0  1274.0       11
# 20259    BAM  112585104     ...          1884.0  3883.0  1477.0       11
# 20260    BAM  112585104     ...           615.0  3629.0  1616.0       11
# 20261    BAM  112585104     ...           399.0  4405.0  1833.0       11
# 20262    BAM  112585104     ...           947.0  3993.0  1926.0       11
#
#        status     mkt_val   group  industry  sector  subindustry
# 20258       A  42698.7038  4020.0  402030.0    40.0   40203010.0
# 20259       A  36629.7341  4020.0  402030.0    40.0   40203010.0
# 20260       A  44565.3048  4020.0  402030.0    40.0   40203010.0
# 20261       A  45671.2297  4020.0  402030.0    40.0   40203010.0
# 20262       A  53474.1592  4020.0  402030.0    40.0   40203010.0
#
# [5 rows x 28 columns]

# %%
# match forward 1year ROA to current leverage
ret['lead_ROA'] = ret.groupby(['ticker'])['ROA'].shift(-4)

# %%
ret.tail()
# Out:
#        fiscalyear_qtr ticker         conpany_name calendaryr_quarter  \
# 667110         2019Q2   CTRM  CASTOR MARITIME INC             2019Q1
# 667111         2019Q3   CTRM  CASTOR MARITIME INC             2019Q2
# 667112         2019Q1   IMUX          IMMUNIC INC             2019Q1
# 667113         2019Q2   IMUX          IMMUNIC INC             2019Q2
# 667114         2019Q3   IMUX          IMMUNIC INC             2019Q3
#
#         total_asset  st_debt  lt_debt  net_income  ebitda  int_exp  exchange  \
# 667110       10.242      0.0      0.0       0.056   0.225      NaN        14
# 667111       10.360      0.0      0.0       0.261   0.421      NaN        14
# 667112          NaN      NaN      NaN      -4.313  -4.157      NaN        14
# 667113       72.574      NaN      NaN     -14.714  -6.783      NaN        14
# 667114       67.604      NaN      NaN      -8.215  -8.068      NaN        14
#
#        status   mkt_val  industry  sector       ROA  total_debt     D/A  \
# 667110      A   13.1282  203030.0    20.0  0.005468         0.0  10.242
# 667111      A   10.2480  203030.0    20.0  0.025193         0.0  10.360
# 667112      A       NaN  352010.0    35.0       NaN         NaN     NaN
# 667113      A  114.5394  352010.0    35.0 -0.202745         NaN     NaN
# 667114      A  100.7100  352010.0    35.0 -0.121516         NaN     NaN
#
#         lead_ROA
# 667110       NaN
# 667111       NaN
# 667112       NaN
# 667113       NaN
# 667114       NaN

# %%
# calculate change in current leverage
ret['1q_before_D/A'] = ret.groupby(['ticker'])['D/A'].shift(1)
ret.tail()
# Out:
#        fiscalyear_qtr ticker         conpany_name calendaryr_quarter  \
# 667110         2019Q2   CTRM  CASTOR MARITIME INC             2019Q1
# 667111         2019Q3   CTRM  CASTOR MARITIME INC             2019Q2
# 667112         2019Q1   IMUX          IMMUNIC INC             2019Q1
# 667113         2019Q2   IMUX          IMMUNIC INC             2019Q2
# 667114         2019Q3   IMUX          IMMUNIC INC             2019Q3
#
#         total_asset  st_debt  lt_debt  net_income  ebitda  int_exp  exchange  \
# 667110       10.242      0.0      0.0       0.056   0.225      NaN        14
# 667111       10.360      0.0      0.0       0.261   0.421      NaN        14
# 667112          NaN      NaN      NaN      -4.313  -4.157      NaN        14
# 667113       72.574      NaN      NaN     -14.714  -6.783      NaN        14
# 667114       67.604      NaN      NaN      -8.215  -8.068      NaN        14
#
#        status   mkt_val  industry  sector       ROA  total_debt     D/A  \
# 667110      A   13.1282  203030.0    20.0  0.005468         0.0  10.242
# 667111      A   10.2480  203030.0    20.0  0.025193         0.0  10.360
# 667112      A       NaN  352010.0    35.0       NaN         NaN     NaN
# 667113      A  114.5394  352010.0    35.0 -0.202745         NaN     NaN
# 667114      A  100.7100  352010.0    35.0 -0.121516         NaN     NaN
#
#         lead_ROA  1q_before_D/A
# 667110       NaN         10.184
# 667111       NaN         10.242
# 667112       NaN            NaN
# 667113       NaN            NaN
# 667114       NaN            NaN

# %%
ret['change_D/A']=(ret['D/A']-ret['1q_before_D/A'])/ret['1q_before_D/A']

# %%
ret[['fiscalyear_qtr', 'ticker','ROA', 'change_D/A', 'mkt_val']].head()
# Out:
#   fiscalyear_qtr ticker       ROA  change_D/A  mkt_val
# 0         1989Q3    AIR  0.015918         NaN      NaN
# 1         1989Q4    AIR  0.016020    0.011707      NaN
# 2         1990Q1    AIR  0.017361   -0.019581      NaN
# 3         1990Q2    AIR  0.000329    0.006856      NaN
# 4         1990Q3    AIR  0.010374   -0.050173      NaN

# %%
# get rid of NAs
ret2=ret[['fiscalyear_qtr', 'ticker','ROA', 'change_D/A']].copy()
print(ret2)
ret2=ret2.dropna()
ret2.head()
# Out:
#        fiscalyear_qtr ticker       ROA  change_D/A
# 0              1989Q3    AIR  0.015918         NaN
# 1              1989Q4    AIR  0.016020    0.011707
# 2              1990Q1    AIR  0.017361   -0.019581
# 3              1990Q2    AIR  0.000329    0.006856
# 4              1990Q3    AIR  0.010374   -0.050173
# 5              1990Q4    AIR  0.010530    0.003452
# 6              1991Q1    AIR  0.009145    0.002061
# 7              1991Q2    AIR  0.006868    0.048792
# 8              1991Q3    AIR  0.007255    0.022925
# 9              1991Q4    AIR  0.002555   -0.025301
# 10             1992Q1    AIR  0.007779    0.022363
# 11             1992Q2    AIR  0.003936    0.014351
# 12             1992Q3    AIR -0.015252   -0.060915
# 13             1992Q4    AIR  0.003588   -0.038867
# 14             1993Q1    AIR  0.006635    0.014796
# 15             1993Q2    AIR  0.005825    0.133008
# 16             1993Q3    AIR  0.005441   -0.003630
# 17             1993Q4    AIR  0.005776    0.021010
# 18             1994Q1    AIR  0.004883   -0.010370
# 19             1994Q2    AIR  0.004998    0.013736
# 20             1994Q3    AIR  0.006761    0.021417
# 21             1994Q4    AIR  0.008255    0.000175
# 22             1995Q1    AIR  0.007842   -0.027384
# 23             1995Q2    AIR  0.008758    0.018272
# 24             1995Q3    AIR  0.009525    0.013756
# 25             1995Q4    AIR  0.011433    0.014934
# 26             1996Q1    AIR  0.010782    0.020487
# 27             1996Q2    AIR  0.010979    0.032559
# 28             1996Q3    AIR  0.011339    0.093503
# 29             1996Q4    AIR  0.013394    0.008364
# ...               ...    ...       ...         ...
# 667085         2019Q3   NMCI  0.008855   -0.016507
# 667086         2016Q1    ACA       NaN         NaN
# 667087         2016Q2    ACA       NaN         NaN
# 667088         2016Q3    ACA       NaN         NaN
# 667089         2016Q4    ACA  0.080587         NaN
# 667090         2017Q1    ACA       NaN         NaN
# 667091         2017Q2    ACA       NaN         NaN
# 667092         2017Q3    ACA       NaN         NaN
# 667093         2017Q4    ACA  0.014727         NaN
# 667094         2018Q1    ACA       NaN         NaN
# 667095         2018Q2    ACA  0.014115         NaN
# 667096         2018Q3    ACA  0.001988    0.005557
# 667097         2018Q4    ACA  0.012752    0.464046
# 667098         2019Q1    ACA  0.012927   -0.036985
# 667099         2019Q2    ACA  0.014642    0.013653
# 667100         2019Q3    ACA  0.014743    0.019770
# 667101         2017Q1   CTRM       NaN         NaN
# 667102         2017Q2   CTRM       NaN         NaN
# 667103         2017Q3   CTRM       NaN         NaN
# 667104         2017Q4   CTRM  0.100826         NaN
# 667105         2018Q1   CTRM       NaN         NaN
# 667106         2018Q2   CTRM       NaN         NaN
# 667107         2018Q3   CTRM       NaN         NaN
# 667108         2018Q4   CTRM  0.055694         NaN
# 667109         2019Q1   CTRM  0.027101    0.058188
# 667110         2019Q2   CTRM  0.005468    0.005695
# 667111         2019Q3   CTRM  0.025193    0.011521
# 667112         2019Q1   IMUX       NaN         NaN
# 667113         2019Q2   IMUX -0.202745         NaN
# 667114         2019Q3   IMUX -0.121516         NaN
#
# [667115 rows x 4 columns]
#   fiscalyear_qtr ticker       ROA  change_D/A
# 1         1989Q4    AIR  0.016020    0.011707
# 2         1990Q1    AIR  0.017361   -0.019581
# 3         1990Q2    AIR  0.000329    0.006856
# 4         1990Q3    AIR  0.010374   -0.050173
# 5         1990Q4    AIR  0.010530    0.003452

# %%
# select the top 1000 market cap company for each quarter
#ret2['rank']=ret2.groupby(['fiscalyear_qtr'])['mkt_val'].rank(ascending = False)

# %%
dates = ret2['fiscalyear_qtr'].unique()
dates
# Out:
# array(['1989Q4', '1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1',
#        '1991Q2', '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3',
#        '1992Q4', '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1',
#        '1994Q2', '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3',
#        '1995Q4', '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1',
#        '1997Q2', '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3',
#        '1998Q4', '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1',
#        '2000Q2', '2000Q3', '2000Q4', '2001Q1', '2001Q2', '2001Q3',
#        '2001Q4', '2002Q1', '2002Q2', '2002Q3', '2002Q4', '2003Q1',
#        '2003Q2', '2003Q3', '2003Q4', '2004Q1', '2004Q2', '2004Q3',
#        '2004Q4', '2005Q1', '2005Q2', '2005Q3', '2005Q4', '2006Q1',
#        '2006Q2', '2006Q3', '2006Q4', '2007Q1', '2007Q2', '2007Q3',
#        '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4', '2009Q1',
#        '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2', '2010Q3',
#        '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1',
#        '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3',
#        '2013Q4', '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1',
#        '2015Q2', '2015Q3', '2015Q4', '2016Q1', '2016Q2', '2016Q3',
#        '2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1',
#        '2018Q2', '2018Q3', '2018Q4', '2019Q1', '2019Q2', '2019Q3',
#        '2019Q4', '2020Q1'], dtype=object)

# %%
for date in dates:
    subdata = ret2[ret2['fiscalyear_qtr']==date]

# %%
def solve_sv_regression(X, Y):

    model = sm.OLS(Y, X)
    
    results_iid = model.fit() # Base case: assuming iid errors
    results_hetero = model.fit(cov_type='HC3') # Adjusted for heteroskedasticity
    results_serial = model.fit(cov_type='HAC',cov_kwds={'maxlags':6, 'use_correction': True})  # adjust for serial correlation
    
    summary = []
    summary.extend((results_iid.params[0],
                    results_iid.bse[0],
                    results_iid.tvalues[0],
                    results_hetero.bse[0],
                    results_hetero.tvalues[0],
                    results_serial.bse[0],
                    results_serial.tvalues[0]))
    return summary

# %%
solve_sv_regression(ret2[ret2['fiscalyear_qtr']=='2008Q1']['ROA'], ret2[ret2['fiscalyear_qtr']=='2008Q1']['change_D/A'])
# Out:
# [0.005041931029899615,
#  0.6347600745336816,
#  0.007943050031310817,
#  0.014168275879261455,
#  0.3558605911450134,
#  0.013453255282707167,
#  0.37477405460227314]

# %%
# 'ROA','change_D/A',
ret2[ret2['fiscalyear_qtr']=='1992Q2']
# Out:
#        fiscalyear_qtr  ticker       ROA  change_D/A
# 11             1992Q2     AIR  0.003936    0.014351
# 129            1992Q2    ACSE -0.056874   -0.023170
# 151            1992Q2  ADCT.1  0.026249   -0.055276
# 236            1992Q2   AELNA -0.001653   -0.012521
# 259            1992Q2   ALO.2  0.012771   -0.002767
# 334            1992Q2    UDI.  0.009750   -0.044833
# 378            1992Q2     AAL -0.010301    0.027886
# 616            1992Q2    ASKI -0.175919   -0.124193
# 633            1992Q2    ASTA  0.032342    0.035970
# 660            1992Q2    ARXX  0.003557   -0.223657
# 731            1992Q2     ASA  0.003841   -0.063234
# 968            1992Q2     PNW  0.007250   -0.007455
# 1207           1992Q2     ABT  0.048704   -0.004194
# 1332           1992Q2  SERV.1  0.003474   -0.023465
# 1416           1992Q2      AK  0.023059   -0.041742
# 1464           1992Q2   AMT.1  0.003404   -0.046096
# 1534           1992Q2  ATVI.1 -0.023139   -0.020414
# 1606           1992Q2   ADAC.  0.050332    0.068881
# 1770           1992Q2   ADIA.  0.012437   -0.006582
# 1788           1992Q2   ADVC.  0.019657    0.026552
# 1811           1992Q2   AROS. -0.006003   -0.019008
# 1833           1992Q2   ADV.2  0.002818    0.002503
# 1879           1992Q2    AQTN  0.026960   -0.019291
# 1905           1992Q2     AMD  0.029310    0.024578
# 2024           1992Q2    MCIP  0.037903   -0.097305
# 2088           1992Q2  ATEL.1  0.016551   -0.043470
# 2098           1992Q2     AET -0.000493    0.003233
# 2213           1992Q2   AFBK.  0.002879   -0.012306
# 2223           1992Q2   AFP.1  0.017401    0.138680
# 2324           1992Q2   AHM.1  0.001435   -0.002742
# ...               ...     ...       ...         ...
# 327412         1992Q2    LAYN  0.015388   -0.030641
# 327526         1992Q2   PACO.  0.001131   -0.409982
# 327566         1992Q2    DKHR -0.000847    0.008335
# 327902         1992Q2     NPL  0.001190   -0.004872
# 327935         1992Q2   TAD.1  0.014074   -0.026675
# 327966         1992Q2    AIHI -0.013738   -0.108175
# 329724         1992Q2    IQSW  0.060746    0.086330
# 329877         1992Q2     GTK -0.023102   -0.028811
# 330136         1992Q2     KEM  0.004038    0.035525
# 330361         1992Q2    CPSS -0.140045    0.081856
# 330725         1992Q2    CITA  0.073258    0.215040
# 331172         1992Q2    PDCO  0.034008    0.076414
# 333696         1992Q2     HSE  0.010315    0.157707
# 334800         1992Q2    SNPL -0.001897   14.270081
# 335184         1992Q2     UVE -0.121827    0.522604
# 335584         1992Q2   CBMI. -0.083613   -0.084421
# 344815         1992Q2    SIND  0.001753    0.049711
# 345907         1992Q2    RELV  0.119034    0.158539
# 352184         1992Q2    RMTR -0.280364   -0.242714
# 356221         1992Q2    SPNS  0.031427    1.002548
# 362221         1992Q2    RAL.  0.017821    0.049624
# 363539         1992Q2    SPTN  0.004643    0.017973
# 366886         1992Q2     BKS -0.010924   -0.005478
# 382479         1992Q2   NTWK.  0.019952   -0.039513
# 387188         1992Q2    NMRX  0.000000   -0.002392
# 389813         1992Q2    THMD -0.028021    0.007500
# 394417         1992Q2    MATW  0.028176    0.037475
# 422046         1992Q2   ENE.1  0.004936    0.007361
# 430382         1992Q2     Q.2  0.010522    0.001975
# 478052         1992Q2   OSFIF  0.037247   -0.070640
#
# [3036 rows x 4 columns]

# %%
a[a['ticker']==True]
# Out:
# Empty DataFrame
# Columns: [ticker, ROA, change_D/A]
# Index: []

# %%
solve_sv_regression(ret2[ret2['fiscalyear_qtr']=='1992Q2']['ROA'], ret2[ret2['fiscalyear_qtr']=='1992Q2']['change_D/A'])
# Out:
# [nan, nan, nan, nan, nan, nan, nan]

# %%
dates = ret2['fiscalyear_qtr'].unique()
dates
# Out:
# array(['1989Q4', '1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1',
#        '1991Q2', '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3',
#        '1992Q4', '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1',
#        '1994Q2', '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3',
#        '1995Q4', '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1',
#        '1997Q2', '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3',
#        '1998Q4', '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1',
#        '2000Q2', '2000Q3', '2000Q4', '2001Q1', '2001Q2', '2001Q3',
#        '2001Q4', '2002Q1', '2002Q2', '2002Q3', '2002Q4', '2003Q1',
#        '2003Q2', '2003Q3', '2003Q4', '2004Q1', '2004Q2', '2004Q3',
#        '2004Q4', '2005Q1', '2005Q2', '2005Q3', '2005Q4', '2006Q1',
#        '2006Q2', '2006Q3', '2006Q4', '2007Q1', '2007Q2', '2007Q3',
#        '2007Q4', '2008Q1', '2008Q2', '2008Q3', '2008Q4', '2009Q1',
#        '2009Q2', '2009Q3', '2009Q4', '2010Q1', '2010Q2', '2010Q3',
#        '2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1',
#        '2012Q2', '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3',
#        '2013Q4', '2014Q1', '2014Q2', '2014Q3', '2014Q4', '2015Q1',
#        '2015Q2', '2015Q3', '2015Q4', '2016Q1', '2016Q2', '2016Q3',
#        '2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1',
#        '2018Q2', '2018Q3', '2018Q4', '2019Q1', '2019Q2', '2019Q3',
#        '2019Q4', '2020Q1'], dtype=object)

# %%
dates = ret2['fiscalyear_qtr'].unique()
for date in dates:
    print(date)
    Y = ret2[ret2['fiscalyear_qtr']==date]['ROA']
    X = ret2[ret2['fiscalyear_qtr']==date]['change_D/A']
    solve_sv_regression(Y,X)
# Out:
# 1989Q4
# 1990Q1
# 1990Q2
# 1990Q3
# 1990Q4
# 1991Q1
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-215-b02e24281a64> in <module>
#       4     Y = ret2[ret2['fiscalyear_qtr']==date]['ROA']
#       5     X = ret2[ret2['fiscalyear_qtr']==date]['change_D/A']
# ----> 6     solve_sv_regression(Y,X)
#
# <ipython-input-208-ef2a71777783> in solve_sv_regression(X, Y)
#       1 def solve_sv_regression(X, Y):
#       2
# ----> 3     model = sm.OLS(Y, X)
#       4
#       5     results_iid = model.fit() # Base case: assuming iid errors
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
#     662         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 663                                   weights=weights, hasconst=hasconst, **kwargs)
#     664         nobs = self.exog.shape[0]
#     665         weights = self.weights
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     177     """
#     178     def __init__(self, endog, exog, **kwargs):
# --> 179         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     180         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     181
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
# ---> 79         self._handle_constant(hasconst)
#      80         self._check_integrity()
#      81         self._cache = resettable_cache()
#
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#     131             ptp_ = self.exog.ptp(axis=0)
#     132             if not np.isfinite(ptp_).all():
# --> 133                 raise MissingDataError('exog contains inf or nans')
#     134             const_idx = np.where(ptp_ == 0)[0].squeeze()
#     135             self.k_constant = const_idx.size
#
# MissingDataError: exog contains inf or nans
