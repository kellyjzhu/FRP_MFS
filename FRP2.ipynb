# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
from sklearn import linear_model

# %%
data = pd.read_csv('data_v1.csv')
name = data.columns.values
name = np.array(['gvkey', 'date', 'fyear', 'fquarter', 'industry_format', 'consol',
       'popsrc', 'datafmt', 'ticker', 'cusip', 'conpany_name', 'currency', 'calendaryr_quarter',
       'fiscalyear_qtr', 'total_asset', 'cash', 'st_debt', 'lt_debt', 'net_income', 'ebitda',
       'int_exp', 'exchange', 'status', 'mkt_val', 'group', 'industry', 'sector',
       'subindustry'])

# %%
data.columns = name
data.head()
# Out:
#    gvkey      date  fyear  fquarter industry_format consol popsrc datafmt  \
# 0   1004  19900228   1989         3            INDL      C      D     STD
# 1   1004  19900531   1989         4            INDL      C      D     STD
# 2   1004  19900831   1990         1            INDL      C      D     STD
# 3   1004  19901130   1990         2            INDL      C      D     STD
# 4   1004  19910228   1990         3            INDL      C      D     STD
#
#   ticker   cusip     ...      net_income  ebitda int_exp exchange  status  \
# 0    AIR  361105     ...           6.109  14.251   2.758       11       A
# 1    AIR  361105     ...           6.224  13.137   2.309       11       A
# 2    AIR  361105     ...           6.697  15.400   2.607       11       A
# 3    AIR  361105     ...           0.126   8.871   2.708       11       A
# 4    AIR  361105     ...           3.977  11.344   2.587       11       A
#
#    mkt_val   group  industry  sector  subindustry
# 0      NaN  2010.0  201010.0    20.0   20101010.0
# 1      NaN  2010.0  201010.0    20.0   20101010.0
# 2      NaN  2010.0  201010.0    20.0   20101010.0
# 3      NaN  2010.0  201010.0    20.0   20101010.0
# 4      NaN  2010.0  201010.0    20.0   20101010.0
#
# [5 rows x 28 columns]

# %%
data[['ticker','exchange']].groupby('ticker').count()
# Out:
#         exchange
# ticker
# A             88
# A.1           20
# A.3           19
# AA            23
# AA.3         107
# AAAB.         19
# AAAP          23
# AABA          89
# AABC          63
# AAC.2         36
# AACC          49
# AACE.         60
# AACG          59
# AACI          28
# AADV          25
# AAE.3         14
# AAF.          35
# AAH           20
# AAI           73
# AAIR.2        14
# AAL          119
# AAL.1         27
# AALR          30
# AAM            8
# AAME         111
# AAN          120
# AANB          66
# AAOI          35
# AAON         119
# AAP           83
# ...          ...
# ZOES          27
# ZOLL          85
# ZOLT          89
# ZOMX          46
# ZONE           9
# ZONS          55
# ZOOM.1        78
# ZPIN          24
# ZRAN          70
# ZRBA          83
# ZRC           22
# ZRN           33
# ZRO           33
# ZS            17
# ZSAN          31
# ZSK            8
# ZSPH          15
# ZTEC          23
# ZTO           23
# ZTR          120
# ZTS           39
# ZU            18
# ZUMZ          67
# ZUO           15
# ZVO           51
# ZVXI          48
# ZYME          19
# ZYNE          27
# ZYXI          83
# ZZ            92
#
# [14110 rows x 1 columns]

# %%
type(data[['ticker','exchange']])
# Out:
# pandas.core.frame.DataFrame

# %%
# remove the duplicates for exchanges 
data[['ticker','exchange']].groupby(data['ticker']).count()
# Out:
#         ticker  exchange
# ticker
# A           88        88
# A.1         20        20
# A.3         19        19
# AA          23        23
# AA.3       107       107
# AAAB.       19        19
# AAAP        23        23
# AABA        89        89
# AABC        63        63
# AAC.2       36        36
# AACC        49        49
# AACE.       60        60
# AACG        59        59
# AACI        28        28
# AADV        25        25
# AAE.3       14        14
# AAF.        35        35
# AAH         20        20
# AAI         73        73
# AAIR.2      14        14
# AAL        119       119
# AAL.1       27        27
# AALR        30        30
# AAM          8         8
# AAME       111       111
# AAN        120       120
# AANB        66        66
# AAOI        35        35
# AAON       119       119
# AAP         83        83
# ...        ...       ...
# ZOES        27        27
# ZOLL        85        85
# ZOLT        89        89
# ZOMX        46        46
# ZONE         9         9
# ZONS        55        55
# ZOOM.1      78        78
# ZPIN        24        24
# ZRAN        70        70
# ZRBA        83        83
# ZRC         22        22
# ZRN         33        33
# ZRO         33        33
# ZS          17        17
# ZSAN        31        31
# ZSK          8         8
# ZSPH        15        15
# ZTEC        23        23
# ZTO         23        23
# ZTR        120       120
# ZTS         39        39
# ZU          18        18
# ZUMZ        67        67
# ZUO         15        15
# ZVO         51        51
# ZVXI        48        48
# ZYME        19        19
# ZYNE        27        27
# ZYXI        83        83
# ZZ          92        92
#
# [14110 rows x 2 columns]

# %%
len(data[data['status']== 'I']['ticker'].unique())
# Out:
# 8536

# %%
8536+5576
# Out:
# 14112

# %%
len(data[data['status']== 'A']['ticker'].unique())
# Out:
# 5576

# %%
# check if any company have 2 status
# if a company is not updated by the database anymore,
# the status changed to I for each time period before

inactive = data[data['status']== 'I']['ticker'].unique()
active = data[data['status']== 'A']['ticker'].unique()
duplicates = []
for ticker in inactive:
    if ticker in active:
        duplicates.append(inactive[i])
duplicates
# Out:
# []

# %%
# 0(n)
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 
   
print(intersection(inactive, active))
# Out:
# []

# %%
len(data['ticker'].unique())
# Out:
# 14111

# %%
data[['status','ticker']].groupby('ticker').count()

# %%
data[['status','ticker']].groupby('ticker').count()
# Out:
#         status
# ticker
# A           88
# A.1         20
# A.3         19
# AA          23
# AA.3       107
# AAAB.       19
# AAAP        23
# AABA        89
# AABC        63
# AAC.2       36
# AACC        49
# AACE.       60
# AACG        59
# AACI        28
# AADV        25
# AAE.3       14
# AAF.        35
# AAH         20
# AAI         73
# AAIR.2      14
# AAL        119
# AAL.1       27
# AALR        30
# AAM          8
# AAME       111
# AAN        120
# AANB        66
# AAOI        35
# AAON       119
# AAP         83
# ...        ...
# ZOES        27
# ZOLL        85
# ZOLT        89
# ZOMX        46
# ZONE         9
# ZONS        55
# ZOOM.1      78
# ZPIN        24
# ZRAN        70
# ZRBA        83
# ZRC         22
# ZRN         33
# ZRO         33
# ZS          17
# ZSAN        31
# ZSK          8
# ZSPH        15
# ZTEC        23
# ZTO         23
# ZTR        120
# ZTS         39
# ZU          18
# ZUMZ        67
# ZUO         15
# ZVO         51
# ZVXI        48
# ZYME        19
# ZYNE        27
# ZYXI        83
# ZZ          92
#
# [14110 rows x 1 columns]

# %%
data[data['ticker']=='TAM']
# Out:
#          gvkey      date  fyear  fquarter industry_format consol popsrc  \
# 666554  311524  20100331   2010         1            INDL      C      D
# 666555  311524  20100630   2010         2            INDL      C      D
# 666556  311524  20100930   2010         3            INDL      C      D
# 666557  311524  20101231   2010         4            INDL      C      D
# 666558  311524  20110331   2011         1            INDL      C      D
# 666559  311524  20110630   2011         2            INDL      C      D
# 666560  311524  20110930   2011         3            INDL      C      D
# 666561  311524  20111231   2011         4            INDL      C      D
# 666562  311524  20120331   2012         1            INDL      C      D
# 666563  311524  20120630   2012         2            INDL      C      D
# 666564  311524  20120930   2012         3            INDL      C      D
# 666565  311524  20121231   2012         4            INDL      C      D
# 666566  311524  20130331   2013         1            INDL      C      D
# 666567  311524  20130630   2013         2            INDL      C      D
# 666568  311524  20130930   2013         3            INDL      C      D
# 666569  311524  20131231   2013         4            INDL      C      D
# 666570  311524  20140331   2014         1            INDL      C      D
# 666571  311524  20140630   2014         2            INDL      C      D
# 666572  311524  20140930   2014         3            INDL      C      D
#
#        datafmt ticker      cusip     ...      net_income ebitda int_exp  \
# 666554     STD    TAM  87509U106     ...             NaN    NaN     NaN
# 666555     STD    TAM  87509U106     ...             NaN    NaN     NaN
# 666556     STD    TAM  87509U106     ...             NaN    NaN     NaN
# 666557     STD    TAM  87509U106     ...             NaN    NaN     NaN
# 666558     STD    TAM  87509U106     ...             NaN    NaN     NaN
# 666559     STD    TAM  87509U106     ...             NaN    NaN     NaN
# 666560     STD    TAM  87509U106     ...             NaN    NaN     NaN
# 666561     STD    TAM  87509U106     ...            30.0  226.9    75.4
# 666562     STD    TAM  87509U106     ...           -43.0    9.0    11.0
# 666563     STD    TAM  87509U106     ...             7.0   68.0    19.0
# 666564     STD    TAM  87509U106     ...             7.0   61.0    20.0
# 666565     STD    TAM  87509U106     ...           -53.0   26.0    28.0
# 666566     STD    TAM  87509U106     ...             8.0   67.0    24.0
# 666567     STD    TAM  87509U106     ...           -13.0   66.0    24.0
# 666568     STD    TAM  87509U106     ...             6.0   64.0    18.0
# 666569     STD    TAM  87509U106     ...            -8.0   52.8    18.0
# 666570     STD    TAM  87509U106     ...            10.0   70.0    18.0
# 666571     STD    TAM  87509U106     ...            14.0   77.0    17.0
# 666572     STD    TAM  87509U106     ...            29.0   75.0    18.0
#
#        exchange  status    mkt_val   group  industry  sector  subindustry
# 666554       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666555       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666556       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666557       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666558       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666559       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666560       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666561       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666562       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666563       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666564       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666565       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666566       11       I        NaN  1510.0  151010.0    15.0   15101050.0
# 666567       11       I  1353.8756  1510.0  151010.0    15.0   15101050.0
# 666568       11       I  1347.8997  1510.0  151010.0    15.0   15101050.0
# 666569       11       I  1342.1663  1510.0  151010.0    15.0   15101050.0
# 666570       11       I  1395.2951  1510.0  151010.0    15.0   15101050.0
# 666571       11       I  1546.1155  1510.0  151010.0    15.0   15101050.0
# 666572       11       I  1736.5896  1510.0  151010.0    15.0   15101050.0
#
# [19 rows x 28 columns]
